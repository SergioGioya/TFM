# %%
import processing_data as pdr

# %%
#Test Mode 
#Example ccaa - 19 Melilla
#ccaa 9 mun 19 -2 - Distrito 2 Barcelona (Cataluña)
#ccaa 1 mun 91 -1 - Distrito 1 Sevilla (Andalucia)
#ccaa 12 mun 1 -1 - Distrito 1 Abegondo (Galicia)
pdr.recommender()
# Out:
# introduzca la ccaa1
# introduzca el municipio91
# introduzca el distrito1
#
# Nuestra recomendación es :
# Guindalera
#
# Segunda Opcion
# Cortes
#  Datos de Guindalera
# Vivienda
# El número total de viviendas es: 22425
# Viviendas Principales: 18605
# Viviendas Secundarias: 1055
# Viviendas Vacias: 2765
# 'Vuelve a Ejecutar la Celda'
